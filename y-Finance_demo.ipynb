# %%
pip show pandas
# Out:
# Name: pandas
# Version: 1.0.5
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: None
# Author-email: None
# License: BSD
# Location: c:\users\hp\anaconda3\lib\site-packages
# Requires: python-dateutil, numpy, pytz
# Required-by: statsmodels, seaborn
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# ...
#
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22622 sha256=05818c5389537583c0282b4c44becef88ae7dd370b8d62303bcefcbedceca201
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\b4\c3\39\9c01ae2b4726f37024bba5592bec868b47a2fab5a786e8979a
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8372 sha256=02cc74588e78bee2965c769599bd2df779a72d202334eb0ac9011c0a5debc164
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\57\6d\a3\a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13
# Successfully built yfinance multitasking
# ...

# %%
import pandas as pd
import yfinance as yf

# %%
# for 1 day with interval 1 minute

tsla_df = yf.download('TSLA GOOG',
                      start = '2020-12-31', 
                      end='2021-01-01', 
                      interval = '1m',
                      progress = False )

# %%
tsla_df.head()
# Out:
#               Adj Close                    Close                     High  \
#                    GOOG        TSLA         GOOG        TSLA         GOOG
# Date
# 2020-12-31  1751.880005  705.669983  1751.880005  705.669983  1758.930054
# 2021-01-04  1728.239990  729.770020  1728.239990  729.770020  1760.650024
# 2021-01-05  1740.920044  735.109985  1740.920044  735.109985  1747.670044
# 2021-01-06  1735.290039  755.979980  1735.290039  755.979980  1748.000000
# 2021-01-07  1787.250000  816.039978  1787.250000  816.039978  1788.400024
#
#                                 Low                     Open              \
#                   TSLA         GOOG        TSLA         GOOG        TSLA
# Date
# 2020-12-31  718.719971  1735.420044  691.119995  1735.420044  699.989990
# 2021-01-04  744.489990  1707.849976  717.190002  1757.540039  719.460022
# 2021-01-05  740.840027  1718.015015  719.200012  1725.000000  723.659973
# ...

# %%
#plotting the entire stock activity using Ticker()
ticker = yf.Ticker('TSLA')

tick_tsla = ticker.history(period = 'max')

tick_tsla['Close'].plot(title = "Stock price")

# %%
tsla_df['Close'].plot(title= "Tesla 1 day with 1 min interval")

# %%
#Practising the Ticker module methods

ticker.info
# Out:
# {'zip': '94304',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 48016,
# ...

# %%
ticker.recommendations
# Out:
#                               Firm     To Grade  From Grade Action
# Date
# 2012-02-16 07:42:00      JP Morgan   Overweight               main
# 2012-02-16 13:53:00     Wunderlich         Hold               down
# 2012-02-17 06:17:00     Oxen Group          Buy               init
# 2012-03-26 07:31:00     Wunderlich          Buy                 up
# 2012-05-22 05:57:00    Maxim Group          Buy               init
# ...                            ...          ...         ...    ...
# 2020-12-03 18:02:28  Goldman Sachs          Buy     Neutral     up
# 2020-12-09 15:34:34      JP Morgan  Underweight               main
# 2020-12-10 12:45:23     New Street      Neutral         Buy   down
# 2020-12-11 11:49:42      Jefferies         Hold         Buy   down
# 2020-12-18 20:57:04           CFRA         Hold  Strong Buy   down
#
# [359 rows x 4 columns]

# %%
ticker.major_holders
# Out:
#         0                                      1
# 0  19.99%        % of Shares Held by All Insider
# 1  42.52%       % of Shares Held by Institutions
# 2  53.14%        % of Float Held by Institutions
# 3    2076  Number of Institutions Holding Shares

# %%
ticker.institutional_holders
# Out:
#                         Holder    Shares Date Reported   % Out        Value
# 0      Capital World Investors  52248658    2020-09-29  0.0551  22415196768
# 1   Vanguard Group, Inc. (The)  43281548    2020-09-29  0.0457  18568216907
# 2               Blackrock Inc.  38019526    2020-09-29  0.0401  16310756849
# 3  Baillie Gifford and Company  34706535    2020-09-29  0.0366  14889450580
# 4      Jennison Associates LLC  18743418    2020-09-29  0.0198   8041113756
# 5     State Street Corporation  15754590    2020-09-29  0.0166   6758876655
# 6                     FMR, LLC  15619293    2020-09-29  0.0165   6700832889
# 7    Goldman Sachs Group, Inc.  11786907    2020-09-29  0.0124   5056700972
# 8    JP Morgan Chase & Company  11341387    2020-09-29  0.0120   4865568436
# 9                   BAMCO Inc.   7321901    2020-09-29  0.0077   3141168748

# %%
ticker.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2020-08-31        0.0           5.0

# %%
ticker.calendar
# Out:
#                                     0                    1
# Earnings Date     2021-01-27 00:00:00  2021-02-01 00:00:00
# Earnings Average                 0.89                 0.89
# Earnings Low                     0.46                 0.46
# Earnings High                    1.16                 1.16
# Revenue Average           10018500000          10018500000
# Revenue Low                9050000000           9050000000
# Revenue High              10683300000          10683300000

# %%
pip install plotly
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11434 sha256=e5a0bfa9757876590628e3a4f7cd11b4e98f81d8550c30505b81920b8d1418e2
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash
# Out:
# ...
#   Created wheel for dash: filename=dash-1.18.1-py3-none-any.whl size=83683 sha256=c1ee572da40dfc03d870fa4a0dfe46408da26c8509ff49f10fc06994e5f7300d
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\33\6f\03\094db0f27625579ae1ae85fb385dedc7e3dc6d8de8cd6146f7
# ...
#   Created wheel for dash-renderer: filename=dash_renderer-1.8.3-py3-none-any.whl size=1013949 sha256=b867df93ff6c6201c49a615387f0917c1314fb3032d5d62af6f7357f2d83aefe
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\82\4d\8c\0764de014b25313cf54199f212bad4fb4b228ecfaef58be3b9
# ...
#   Created wheel for dash-core-components: filename=dash_core_components-1.14.1-py3-none-any.whl size=3525934 sha256=2df551f928845acc1be947c90e68a8d8d34647d0b401c25fab2cd134909d5cd7
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\4f\83\9f\bf95c8533a915b0588f84324257ae92bc1207d325000c9fa5e
# ...

# %% [markdown]
# <h2>Fetch stock info of last 1 day</h2>

# %%
from datetime import date,timedelta
import numpy as np

# %%
print(date.today())
b = timedelta(days = 7)
print(date.today()-b)
# Out:
# 2021-01-14
# 2021-01-07

# %%
b = timedelta(days = 7)
tsla_df = yf.download('TSLA',
                      start = date.today()-b,
                      end = date.today(),
                     interval = "1m",
                     progress=False)

# %%
day_1_df = tsla_df.tail(1)
day_1_df.index[0]
# Out:
# Timestamp('2021-01-14 00:00:00')

# %%
# type(day_1_df['Open'][0])
# day_1_df
# np.array2string(day_1_df)

# %%
day_1_df.values[0][0]
# Out:
# 852.760009765625

# %%
d = str(day_1_df.index[0].date())
result = day_1_df.index.name + ": " + d + "\n"
# result

for i in range(0,len(day_1_df.columns)):
    result = result+ day_1_df.columns[i] + ": " + str(day_1_df.values[0][i]) + "\n"
    
result
# Out:
# 'Date: 2021-01-14\nOpen: 843.3900146484375\nHigh: 863.0\nLow: 838.75\nClose: 845.0\nAdj Close: 845.0\nVolume: 31173200.0\n'

# %%
len(day_1_df.columns)
# Out:
# 6

# %%
tsla_df = yf.download('TSLA',
                      start = date.today()-b,
                      end = date.today(),
                      period = '5d',
                     interval = "1m",
                     progress=False)
tsla_df = tsla_df.tail(60)

# %%
ticker = yf.Ticker('TSLA')
tesla_tick = ticker.history(period= '5d', interval = '1m')
tesla_tick = tesla_tick.tail(60)
tesla_tick['Close'].plot(title= ticker.info['shortName'] + " hourly trend")

# %%
hourly = tsla_df.tail(60)
hourly
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2021-01-14 15:00:00-05:00  848.770020  849.830017  848.143188  849.500000
# 2021-01-14 15:01:00-05:00  849.530029  849.739990  849.190002  849.250000
# 2021-01-14 15:02:00-05:00  849.217285  849.359985  848.510010  848.559998
# 2021-01-14 15:03:00-05:00  848.489990  848.659973  848.049988  848.299988
# 2021-01-14 15:04:00-05:00  848.400024  848.700012  848.210022  848.570007
# 2021-01-14 15:05:00-05:00  848.700012  849.150024  848.698975  848.750000
# 2021-01-14 15:06:00-05:00  848.876892  848.940002  848.640625  848.750000
# 2021-01-14 15:07:00-05:00  848.750000  848.825012  847.710022  847.835022
# 2021-01-14 15:08:00-05:00  847.869995  848.159912  847.390076  847.909973
# 2021-01-14 15:09:00-05:00  847.830017  847.840027  846.500000  846.796997
# 2021-01-14 15:10:00-05:00  846.784973  847.495972  846.700012  847.341797
# ...

# %%
ticker.info['shortName']
# Out:
# 'Tesla, Inc.'

# %%
import plotly.express as px

# %%
#'Open', 'High', 'Low', 'Close', 'Adj Close'


# df_info = tsla_df[{'Open', 'High', 'Low', 'Close', 'Adj Close'}]
df_info = tsla_df['Close'].copy()
df_info.loc[:, 'Datetime'] = df_info.index




fig = px.line(df_info, 
              x = 'Datetime',
              y = list(df_info.keys())
#               title = ticker.info['shortName'] + " Share Prices "+
#              str(tesla_tick.index[0].time())
#               + " to " +str(tesla_tick.index[len(tesla_tick.index) - 1].time())
             )
fig.show()
# Out:
# <div>                            <div id="26efa8c3-b6fd-4340-999d-3408e981d466" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26efa8c3-b6fd-4340-999d-3408e981d466")) {                    Plotly.newPlot(                        "26efa8c3-b6fd-4340-999d-3408e981d466",                        [{"hovertemplate": "variable=GOOG<br>Datetime=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "GOOG", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "GOOG", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-12-31T09:30:00-05:00", "2020-12-31T09:31:00-05:00", "2020-12-31T09:32:00-05:00", "2020-12-31T09:33:00-05:00", "2020-12-31T09:34:00-05:00", "2020-12-31T09:35:00-05:00", "2020-12-31T09:36:00-05:00", "2020-12-31T09:
# ...

# %%
import os

# %%
tesla_tick[{'Open', 'Close'}]
# Out:
#                                 Close        Open
# Datetime
# 2021-01-15 09:30:00-05:00  854.452087  853.580017
# 2021-01-15 09:31:00-05:00  858.654297  854.349976
# 2021-01-15 09:32:00-05:00  857.890015  858.583008
# 2021-01-15 09:33:00-05:00  857.589722  857.890015
# 2021-01-15 09:34:00-05:00  854.424500  857.580017
# ...                               ...         ...
# 2021-01-15 12:09:00-05:00  840.070007  839.559998
# 2021-01-15 12:10:00-05:00  839.960022  840.189880
# 2021-01-15 12:11:00-05:00  839.038574  839.719971
# 2021-01-15 12:12:00-05:00  839.520081  838.859985
# 2021-01-15 12:13:01-05:00  839.390015  839.390015
#
# [164 rows x 2 columns]

# %% [markdown]
# <h3>Plotly Orca is required to save Plotly images offline</h3>

# %%
conda install -c plotly plotly-orca
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\HP\anaconda3
#
#   added / updated specs:
#     - plotly-orca
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.9.2                |   py38haa95532_0         2.9 MB
#     plotly-orca-1.3.1          |                1        56.8 MB  plotly
#     ------------------------------------------------------------
#                                            Total:        59.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   plotly-orca        plotly/win-64::plotly-orca-1.3.1-1
#
# The following packages will be UPDATED:
#
#   conda                                        4.8.5-py38_0 --> 4.9.2-py38haa95532_0
#
#
#
# ...
#
# conda-4.9.2          | 2.9 MB    |            |   0%
# conda-4.9.2          | 2.9 MB    |            |   1%
# ...

# %%
if not os.path.exists("images"):
    os.mkdir("images")

fig.write_image("images/plot.png")

# %%
str(tesla_tick.index[len(tesla_tick.index) - 1].time())
# Out:
# '15:59:00'

# %%
tsla_df.index
# Out:
# DatetimeIndex(['2021-01-08', '2021-01-11', '2021-01-12', '2021-01-13',
#                '2021-01-14'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
tesla_tick.keys()
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
plot_df = tesla_tick[{'Open', 'High', 'Low', 'Close'}]
plot_df
# Out:
#                                 Close        Open         Low        High
# Datetime
# 2021-01-15 09:30:00-05:00  854.452087  853.580017  852.606018  854.510010
# 2021-01-15 09:31:00-05:00  858.654297  854.349976  853.260010  858.799988
# 2021-01-15 09:32:00-05:00  857.890015  858.583008  855.090027  858.820007
# 2021-01-15 09:33:00-05:00  857.589722  857.890015  856.300110  859.900024
# 2021-01-15 09:34:00-05:00  854.424500  857.580017  853.000000  858.330017
# ...                               ...         ...         ...         ...
# 2021-01-15 12:09:00-05:00  840.070007  839.559998  839.150024  840.219971
# 2021-01-15 12:10:00-05:00  839.960022  840.189880  839.166016  840.284973
# 2021-01-15 12:11:00-05:00  839.038574  839.719971  838.500122  839.804993
# 2021-01-15 12:12:00-05:00  839.520081  838.859985  838.609985  839.869995
# 2021-01-15 12:13:01-05:00  839.390015  839.390015  839.390015  839.390015
#
# [164 rows x 4 columns]

# %%
date_arr = np.asarray(tsla_df.index)
date_df = pd.DataFrame(date_arr, columns = ['Date'])
date_df
# Out:
#                           Date
# 0    2021-01-08 09:30:00-05:00
# 1    2021-01-08 09:31:00-05:00
# 2    2021-01-08 09:32:00-05:00
# 3    2021-01-08 09:33:00-05:00
# 4    2021-01-08 09:34:00-05:00
# ...                        ...
# 1944 2021-01-14 15:55:00-05:00
# 1945 2021-01-14 15:56:00-05:00
# 1946 2021-01-14 15:57:00-05:00
# 1947 2021-01-14 15:58:00-05:00
# 1948 2021-01-14 15:59:00-05:00
#
# [1949 rows x 1 columns]

# %%
type(tsla_df[{'Open', 'High', 'Low', 'Close', 'Adj Close'}])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_date)
# Out:
# pandas.core.frame.DataFrame

# %%
list(df_all.keys())
# Out:
# ['Date', 'Adj Close', 'Close', 'High', 'Open', 'Low']

# %%
# df_all

# %%
tsla_df.info
# Out:
# <bound method DataFrame.info of                              Adj Close                    Close              \
#                                   GOOG        TSLA         GOOG        TSLA
# Datetime
# 2020-12-31 09:30:00-05:00  1740.689941  700.239990  1740.689941  700.239990
# 2020-12-31 09:31:00-05:00  1742.239990  701.734985  1742.239990  701.734985
# 2020-12-31 09:32:00-05:00  1745.459961  702.109985  1745.459961  702.109985
# 2020-12-31 09:33:00-05:00  1748.189941  699.700012  1748.189941  699.700012
# 2020-12-31 09:34:00-05:00  1749.790039  698.380005  1749.790039  698.380005
# ...                                ...         ...          ...         ...
# 2020-12-31 15:55:00-05:00  1750.989990  705.119995  1750.989990  705.119995
# 2020-12-31 15:56:00-05:00  1752.290039  705.688721  1752.290039  705.688721
# 2020-12-31 15:57:00-05:00  1752.479980  706.090027  1752.479980  706.090027
# 2020-12-31 15:58:00-05:00  1752.199951  706.469971  1752.199951  706.469971
# ...

# %%
ticker = yf.Ticker('TSLA GOOG')

# %%
tick_2 = ticker.history(period = '5d')
# Out:
# - TSLA GOOG: No data found, symbol may be delisted

# %%
tick_2.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []>

# %%
df_info
# Out:
#            GOOG        TSLA   Datetime
# 0   1751.880005  705.669983 2020-12-31
# 1   1728.239990  729.770020 2021-01-04
# 2   1740.920044  735.109985 2021-01-05
# 3   1735.290039  755.979980 2021-01-06
# 4   1787.250000  816.039978 2021-01-07
# 5   1807.209961  880.020020 2021-01-08
# 6   1766.719971  811.190002 2021-01-11
# 7   1746.550049  849.440002 2021-01-12
# 8   1754.400024  854.409973 2021-01-13
# 9   1740.180054  845.000000 2021-01-14
# 10  1736.189941  826.159973 2021-01-15
# 11  1790.859985  844.549988 2021-01-19
# 12  1886.900024  850.450012 2021-01-20
# 13  1929.959961  848.609985 2021-01-21

# %%
df_info.reset_index(drop=True, inplace = True)

# %%
list(df_info.keys())
# Out:
# ['GOOG', 'TSLA', 'Datetime']

# %%
df_info
# Out:
# Datetime
# 2021-01-14 09:30:00-05:00                                                845.6
# 2021-01-14 09:31:00-05:00                                              845.802
# 2021-01-14 09:32:00-05:00                                               844.29
# 2021-01-14 09:33:00-05:00                                              841.511
# 2021-01-14 09:34:00-05:00                                               842.73
#                                                    ...
# 2021-01-20 15:56:00-05:00                                               851.36
# 2021-01-20 15:57:00-05:00                                               851.44
# 2021-01-20 15:58:00-05:00                                              851.104
# 2021-01-20 15:59:00-05:00                                               850.65
# TSLA                         Datetime
# 2021-01-14 09:30:00-05:00    845.5999...
# Name: Close, Length: 1549, dtype: object

# %%
tsla_df['Close']
# Out:
#                                   GOOG        TSLA
# Datetime
# 2020-12-31 09:30:00-05:00  1740.689941  700.239990
# 2020-12-31 09:31:00-05:00  1742.239990  701.734985
# 2020-12-31 09:32:00-05:00  1745.459961  702.109985
# 2020-12-31 09:33:00-05:00  1748.189941  699.700012
# 2020-12-31 09:34:00-05:00  1749.790039  698.380005
# ...                                ...         ...
# 2020-12-31 15:55:00-05:00  1750.989990  705.119995
# 2020-12-31 15:56:00-05:00  1752.290039  705.688721
# 2020-12-31 15:57:00-05:00  1752.479980  706.090027
# 2020-12-31 15:58:00-05:00  1752.199951  706.469971
# 2020-12-31 15:59:00-05:00  1753.329956  705.210022
#
# [390 rows x 2 columns]

# %%
pd.DataFrame(tsla_df['Close'])
# Out:
#                                   GOOG        TSLA
# Datetime
# 2020-12-31 09:30:00-05:00  1740.689941  700.239990
# 2020-12-31 09:31:00-05:00  1742.239990  701.734985
# 2020-12-31 09:32:00-05:00  1745.459961  702.109985
# 2020-12-31 09:33:00-05:00  1748.189941  699.700012
# 2020-12-31 09:34:00-05:00  1749.790039  698.380005
# ...                                ...         ...
# 2020-12-31 15:55:00-05:00  1750.989990  705.119995
# 2020-12-31 15:56:00-05:00  1752.290039  705.688721
# 2020-12-31 15:57:00-05:00  1752.479980  706.090027
# 2020-12-31 15:58:00-05:00  1752.199951  706.469971
# 2020-12-31 15:59:00-05:00  1753.329956  705.210022
#
# [390 rows x 2 columns]
